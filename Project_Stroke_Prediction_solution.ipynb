# %% [markdown]
# #Full DL Solution
#
# © 2023, Zaka AI, Inc. All Rights Reserved.
#
# ---
#
# ###**Case Study:** Stroke Prediction
#
# **Objective:** The goal of this project is to walk you through a case study where you can apply the deep learning concepts that you learned about during the week. By the end of this project, you would have developed a solution that predicts if a person will have a stroke or not.

# %% [markdown]
# **Dataset Explanation:** We will be using the stroke dataset. Its features are:
#
#
# * **id:** unique identifier
# * **gender:** "Male", "Female" or "Other"
# * **age:** age of the patient
# * **hypertension:** 0 if the patient doesn't have hypertension, 1 if the patient has hypertension
# * **heart_disease:** 0 if the patient doesn't have any heart diseases, 1 if the patient has a heart disease
# * **ever_married:** "No" or "Yes"
# * **work_type:** "children", "Govt_jov", "Never_worked", "Private" or "Self-employed"
# * **Residence_type:** "Rural" or "Urban"
# * **avg_glucose_level:** average glucose level in blood
# * **bmi:** body mass index
# * **smoking_status:** "formerly smoked", "never smoked", "smokes" or "Unknown"*
# * **stroke:** 1 if the patient had a stroke or 0 if not

# %% [markdown]
# #Importing Libraries

# %%
pip install scikeras
# Out:
# Collecting scikeras
#   Downloading scikeras-0.11.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: packaging>=0.21 in /usr/local/lib/python3.10/dist-packages (from scikeras) (23.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikeras) (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras) (1.11.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras) (3.2.0)
# Installing collected packages: scikeras
# Successfully installed scikeras-0.11.0

# %% [markdown]
# We start by importing the libraries: numpy and pandas

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization
from keras.metrics import Precision, Recall
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import GridSearchCV
from scikeras.wrappers import KerasClassifier

# %% [markdown]
# #Loading the Dataset

# %% [markdown]
# We load the dataset from a csv file, and see its first rows

# %%
data = pd.read_csv('healthcare-dataset-stroke-data.csv')
data.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
# #Exploratory Data Analysis

# %% [markdown]
# Now we start the exploratory data analysis.

# %% [markdown]
# ###Shape of the data

# %% [markdown]
# First, you need to know the shape of our data (How many examples and features do we have)

# %%
print("We have {} row and {} columns".format(data.shape[0], data.shape[1]))
# Out:
# We have 5110 row and 12 columns

# %% [markdown]
# ###Types of different Columns

# %% [markdown]
# See the type of each of your features and see if you have any nulls

# %%
data.info()
data.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %% [markdown]
# ###Dealing with categorical variables

# %% [markdown]
# Now we will walk through the categorical variables that we have to see the categories and the counts of each of them.

# %%
categ_columns = ['gender','ever_married','work_type', 'Residence_type', 'smoking_status']
for col in categ_columns:
    print("{}\n".format(data[col].value_counts()))
# Out:
# Female    2994
# Male      2115
# Other        1
# Name: gender, dtype: int64
#
# Yes    3353
# No     1757
# Name: ever_married, dtype: int64
#
# Private          2925
# Self-employed     819
# children          687
# Govt_job          657
# Never_worked       22
# Name: work_type, dtype: int64
#
# Urban    2596
# Rural    2514
# Name: Residence_type, dtype: int64
#
# never smoked       1892
# Unknown            1544
# formerly smoked     885
# smokes              789
# Name: smoking_status, dtype: int64

# %% [markdown]
# #Preprocessing

# %% [markdown]
# Prepare the data in a way to be ready to be used to train a DL model.

# %%
#dropping unused columns
data.drop('id', axis=1, inplace=True)

# %%
#dropping missing values
data = data.dropna()
data.isnull().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
#Converting categorical columns to numerical
encoder = LabelEncoder()
for col in categ_columns:
    data[col] = encoder.fit_transform(data[col])

# %%
#Normalization
scaler = MinMaxScaler()
scaler.fit(data)
data = pd.DataFrame(scaler.transform(data), columns=data.columns)

# %%
#checking the data after preprocessing
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4909 entries, 0 to 4908
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             4909 non-null   float64
#  1   age                4909 non-null   float64
#  2   hypertension       4909 non-null   float64
#  3   heart_disease      4909 non-null   float64
#  4   ever_married       4909 non-null   float64
#  5   work_type          4909 non-null   float64
#  6   Residence_type     4909 non-null   float64
#  7   avg_glucose_level  4909 non-null   float64
#  8   bmi                4909 non-null   float64
#  9   smoking_status     4909 non-null   float64
#  10  stroke             4909 non-null   float64
# dtypes: float64(11)
# memory usage: 422.0 KB
#             gender          age  hypertension  heart_disease  ever_married  \
# count  4909.000000  4909.000000   4909.000000    4909.000000   4909.000000
# mean      0.205032     0.522282      0.091872       0.049501      0.652679
# std       0.246154     0.275331      0.288875       0.216934      0.476167
# min       0.000000     0.000000      0.000000       0.000000      0.000000
# 25%       0.000000     0.304199      0.000000       0.000000      0.000000
# 50%       0.000000     0.536133      0.000000       0.000000      1.000000
# 75%       0.500000     0.731445      0.000000       0.000000      1.000000
# max       1.000000     1.000000      1.000000       1.000000      1.000000
#
#          work_type  Residence_type  avg_glucose_level          bmi  \
# count  4909.000000     4909.000000        4909.000000  4909.000000
# mean      0.542524        0.507232           0.231674     0.212981
# std       0.273148        0.499999           0.205080     0.089966
# min       0.000000        0.000000           0.000000     0.000000
# 25%       0.500000        0.000000           0.101330     0.151203
# 50%       0.500000        1.000000           0.168775     0.203895
# 75%       0.750000        1.000000           0.269827     0.261168
# max       1.000000        1.000000           1.000000     1.000000
#
#        smoking_status       stroke
# count     4909.000000  4909.000000
# mean         0.458478     0.042575
# std          0.355774     0.201917
# min          0.000000     0.000000
# 25%          0.000000     0.000000
# 50%          0.666667     0.000000
# 75%          0.666667     0.000000
# max          1.000000     1.000000

# %% [markdown]
# #Building the DL Model

# %% [markdown]
# Now it's time to build the actual model. Propose a DL architecture suitable for this problem and print its summary.

# %%
def create_model():
    model = Sequential()
    model.add(Dense(32, input_dim=10, activation='relu'))
    model.add(Dense(16, activation='relu'))
    model.add(Dense(4, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    return model

model = create_model()
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 32)                352
#
#  dense_5 (Dense)             (None, 16)                528
#
#  dense_6 (Dense)             (None, 4)                 68
#
#  dense_7 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 953 (3.72 KB)
# Trainable params: 953 (3.72 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ###Compiling the model

# %% [markdown]
# Now we need to compile the model.

# %%
model.compile(loss='binary_crossentropy',optimizer='adam', metrics=['accuracy', Precision(thresholds = 0.5), Recall(thresholds = 0.5)])

# %% [markdown]
# ###Fitting the model

# %% [markdown]
# we split our dataset between training and testing, and we fit the model on training data (70%), and validate on the testing data (30%).

# %%
X = data.drop('stroke', axis=1)
y = data['stroke']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=97)

model.fit(X_train, y_train, validation_data=(X_test,y_test), epochs=30, batch_size=100)
# Out:
# Epoch 1/30
# 35/35 [==============================] - 3s 23ms/step - loss: 0.5808 - accuracy: 0.8350 - precision: 0.0700 - recall: 0.2282 - val_loss: 0.4442 - val_accuracy: 0.9593 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/30
# 35/35 [==============================] - 0s 7ms/step - loss: 0.3466 - accuracy: 0.9566 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2482 - val_accuracy: 0.9593 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/30
# 35/35 [==============================] - 0s 9ms/step - loss: 0.2114 - accuracy: 0.9566 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1864 - val_accuracy: 0.9593 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/30
# 35/35 [==============================] - 0s 9ms/step - loss: 0.1882 - accuracy: 0.9566 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1781 - val_accuracy: 0.9593 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/30
# 35/35 [==============================] - 0s 7ms/step - loss: 0.1802 - accuracy: 0.9566 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1718 - val_accuracy: 0.9593 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/30
# 35/35 [==============================] - 0s 8ms/step - loss: 0.1733 - accuracy: 0.9566 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1666 - val_accuracy: 0.9593 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/30
# 35/35 [==============================] - 0s 12ms/step - loss: 0.1678 - accuracy: 0.9566 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1619 - val_accuracy: 0.9593 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/30
# 35/35 [==============================] - 0s 11ms/step - loss: 0.1636 - accuracy: 0.9566 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1586 - val_accuracy: 0.9593 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/30
# 35/35 [==============================] - 0s 8ms/step - loss: 0.1592 - accuracy: 0.9566 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1565 - val_accuracy: 0.9593 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/30
# 35/35 [==============================] - 0s 11ms/step - loss: 0.1559 - accuracy: 0.9566 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1545 - val_accuracy: 0.9593 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/30
# 35/35 [==============================] - 0s 7ms/step - loss: 0.1534 - accuracy: 0.9566 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1512 - val_accuracy: 0.9593 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/30
# 35/35 [==============================] - 0s 8ms/step - loss: 0.1502 - accuracy: 0.9566 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1492 - val_accuracy: 0.9593 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/30
# 35/35 [==============================] - 0s 8ms/step - loss: 0.1485 - accuracy: 0.9566 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1482 - val_accuracy: 0.9593 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/30
# 35/35 [==============================] - 0s 8ms/step - loss: 0.1459 - accuracy: 0.9566 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1474 - val_accuracy: 0.9593 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/30
# 35/35 [==============================] - 0s 13ms/step - loss: 0.1446 - accuracy: 0.9566 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1455 - val_accuracy: 0.9593 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/30
# 35/35 [==============================] - 0s 8ms/step - loss: 0.1440 - accuracy: 0.9566 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1473 - val_accuracy: 0.9593 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/30
# 35/35 [==============================] - 0s 10ms/step - loss: 0.1418 - accuracy: 0.9566 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1448 - val_accuracy: 0.9593 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/30
# 35/35 [==============================] - 0s 11ms/step - loss: 0.1404 - accuracy: 0.9566 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1443 - val_accuracy: 0.9593 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/30
# 35/35 [==============================] - 0s 13ms/step - loss: 0.1396 - accuracy: 0.9566 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1437 - val_accuracy: 0.9593 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/30
# 35/35 [==============================] - 1s 16ms/step - loss: 0.1385 - accuracy: 0.9566 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1452 - val_accuracy: 0.9593 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 21/30
# 35/35 [==============================] - 1s 14ms/step - loss: 0.1378 - accuracy: 0.9566 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1447 - val_accuracy: 0.9593 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 22/30
# 35/35 [==============================] - 0s 8ms/step - loss: 0.1379 - accuracy: 0.9566 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1455 - val_accuracy: 0.9593 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 23/30
# 35/35 [==============================] - 1s 15ms/step - loss: 0.1363 - accuracy: 0.9566 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1458 - val_accuracy: 0.9593 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 24/30
# 35/35 [==============================] - 0s 13ms/step - loss: 0.1361 - accuracy: 0.9566 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1454 - val_accuracy: 0.9593 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 25/30
# 35/35 [==============================] - 1s 15ms/step - loss: 0.1361 - accuracy: 0.9566 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1455 - val_accuracy: 0.9593 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 26/30
# 35/35 [==============================] - 0s 12ms/step - loss: 0.1353 - accuracy: 0.9566 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1456 - val_accuracy: 0.9593 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 27/30
# 35/35 [==============================] - 0s 9ms/step - loss: 0.1346 - accuracy: 0.9566 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1456 - val_accuracy: 0.9593 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 28/30
# 35/35 [==============================] - 0s 7ms/step - loss: 0.1344 - accuracy: 0.9566 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1460 - val_accuracy: 0.9593 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 29/30
# 35/35 [==============================] - 0s 6ms/step - loss: 0.1339 - accuracy: 0.9566 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1459 - val_accuracy: 0.9593 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 30/30
# 35/35 [==============================] - 0s 8ms/step - loss: 0.1343 - accuracy: 0.9569 - precision: 1.0000 - recall: 0.0067 - val_loss: 0.1459 - val_accuracy: 0.9593 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %%
#Evaulation
scores = model.evaluate(X_test, y_test)
print('Accurcay : {}'.format(scores[1]))
print('Precision : {}'.format(scores[2]))
print('Recall : {}'.format(scores[3]))
# Out:
# 47/47 [==============================] - 0s 2ms/step - loss: 0.1459 - accuracy: 0.9593 - precision: 0.0000e+00 - recall: 0.0000e+00
# Accurcay : 0.9592667818069458
# Precision : 0.0
# Recall : 0.0

# %% [markdown]
# What can you deduce from the results you obtained?

# %% [markdown]
# **[The model's accuracy is high but that's only because it predicted the negative cases only, it didn't learn from the positive cases since precision and recall both equal to zero ]**

# %% [markdown]
# #Improving DL Models

# %% [markdown]
# **TIP: When tuning your model to obtain a better performance, make sure you use a validation set**

# %% [markdown]
# ###Data Improvement

# %% [markdown]
# After having studied your data in previous parts, enhance the performance of your model with one data improvement using **SMOTE**.

# %%
print('Classes counts before using SMOTE :\n{}'.format(y.value_counts()))
# Out:
# Classes counts before using SMOTE :
# 0.0    4700
# 1.0     209
# Name: stroke, dtype: int64

# %%
#Applying SMOTE
smote = SMOTE(sampling_strategy='auto', random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)
print('Classes counts after using SMOTE :\n{}'.format(y_resampled.value_counts()))
# Out:
# Classes counts after using SMOTE :
# 1.0    4700
# 0.0    4700
# Name: stroke, dtype: int64

# %% [markdown]
# Comment the performance you obtained

# %%
#Training and fitting the model on the resampled data
X_train_s, X_test_s, y_train_s, y_test_s = train_test_split(X_resampled, y_resampled, test_size=0.3)
model.fit(X_train_s, y_train_s, validation_data=(X_test_s, y_test_s), epochs=30, batch_size=100)
# Out:
# Epoch 1/30
# 66/66 [==============================] - 0s 4ms/step - loss: 0.5590 - accuracy: 0.7140 - precision: 0.6960 - recall: 0.7713 - val_loss: 0.4490 - val_accuracy: 0.7794 - val_precision: 0.7440 - val_recall: 0.8339
# Epoch 2/30
# 66/66 [==============================] - 0s 3ms/step - loss: 0.4390 - accuracy: 0.7907 - precision: 0.7627 - recall: 0.8509 - val_loss: 0.4243 - val_accuracy: 0.7890 - val_precision: 0.7583 - val_recall: 0.8318
# Epoch 3/30
# 66/66 [==============================] - 0s 3ms/step - loss: 0.4288 - accuracy: 0.7891 - precision: 0.7593 - recall: 0.8533 - val_loss: 0.4176 - val_accuracy: 0.7887 - val_precision: 0.7551 - val_recall: 0.8376
# Epoch 4/30
# 66/66 [==============================] - 0s 3ms/step - loss: 0.4238 - accuracy: 0.7906 - precision: 0.7623 - recall: 0.8512 - val_loss: 0.4154 - val_accuracy: 0.7908 - val_precision: 0.7534 - val_recall: 0.8478
# Epoch 5/30
# 66/66 [==============================] - 0s 3ms/step - loss: 0.4217 - accuracy: 0.7968 - precision: 0.7696 - recall: 0.8536 - val_loss: 0.4148 - val_accuracy: 0.7911 - val_precision: 0.7685 - val_recall: 0.8172
# Epoch 6/30
# 66/66 [==============================] - 0s 3ms/step - loss: 0.4194 - accuracy: 0.7942 - precision: 0.7657 - recall: 0.8545 - val_loss: 0.4117 - val_accuracy: 0.7904 - val_precision: 0.7628 - val_recall: 0.8267
# Epoch 7/30
# 66/66 [==============================] - 0s 3ms/step - loss: 0.4136 - accuracy: 0.7988 - precision: 0.7697 - recall: 0.8590 - val_loss: 0.4066 - val_accuracy: 0.7996 - val_precision: 0.7613 - val_recall: 0.8572
# Epoch 8/30
# 66/66 [==============================] - 0s 3ms/step - loss: 0.4117 - accuracy: 0.7995 - precision: 0.7692 - recall: 0.8623 - val_loss: 0.4052 - val_accuracy: 0.8004 - val_precision: 0.7573 - val_recall: 0.8682
# Epoch 9/30
# 66/66 [==============================] - 0s 3ms/step - loss: 0.4069 - accuracy: 0.8041 - precision: 0.7742 - recall: 0.8647 - val_loss: 0.4019 - val_accuracy: 0.7979 - val_precision: 0.7540 - val_recall: 0.8682
# Epoch 10/30
# 66/66 [==============================] - 0s 3ms/step - loss: 0.4046 - accuracy: 0.8030 - precision: 0.7697 - recall: 0.8711 - val_loss: 0.4023 - val_accuracy: 0.7950 - val_precision: 0.7817 - val_recall: 0.8034
# Epoch 11/30
# 66/66 [==============================] - 0s 3ms/step - loss: 0.4044 - accuracy: 0.8067 - precision: 0.7754 - recall: 0.8696 - val_loss: 0.3963 - val_accuracy: 0.8004 - val_precision: 0.7729 - val_recall: 0.8354
# Epoch 12/30
# 66/66 [==============================] - 0s 3ms/step - loss: 0.4001 - accuracy: 0.8078 - precision: 0.7743 - recall: 0.8747 - val_loss: 0.3986 - val_accuracy: 0.7982 - val_precision: 0.7769 - val_recall: 0.8216
# Epoch 13/30
# 66/66 [==============================] - 0s 3ms/step - loss: 0.3980 - accuracy: 0.8074 - precision: 0.7745 - recall: 0.8735 - val_loss: 0.3938 - val_accuracy: 0.7996 - val_precision: 0.7730 - val_recall: 0.8332
# Epoch 14/30
# 66/66 [==============================] - 0s 3ms/step - loss: 0.3978 - accuracy: 0.8079 - precision: 0.7769 - recall: 0.8699 - val_loss: 0.3919 - val_accuracy: 0.8071 - val_precision: 0.7570 - val_recall: 0.8893
# Epoch 15/30
# 66/66 [==============================] - 0s 3ms/step - loss: 0.3938 - accuracy: 0.8112 - precision: 0.7759 - recall: 0.8813 - val_loss: 0.3905 - val_accuracy: 0.8035 - val_precision: 0.7584 - val_recall: 0.8755
# Epoch 16/30
# 66/66 [==============================] - 0s 3ms/step - loss: 0.3917 - accuracy: 0.8120 - precision: 0.7782 - recall: 0.8786 - val_loss: 0.3848 - val_accuracy: 0.8082 - val_precision: 0.7667 - val_recall: 0.8711
# Epoch 17/30
# 66/66 [==============================] - 0s 3ms/step - loss: 0.3909 - accuracy: 0.8114 - precision: 0.7770 - recall: 0.8795 - val_loss: 0.3887 - val_accuracy: 0.8117 - val_precision: 0.7548 - val_recall: 0.9082
# Epoch 18/30
# 66/66 [==============================] - 0s 3ms/step - loss: 0.3887 - accuracy: 0.8131 - precision: 0.7776 - recall: 0.8828 - val_loss: 0.3829 - val_accuracy: 0.8092 - val_precision: 0.7688 - val_recall: 0.8696
# Epoch 19/30
# 66/66 [==============================] - 0s 3ms/step - loss: 0.3874 - accuracy: 0.8137 - precision: 0.7787 - recall: 0.8822 - val_loss: 0.3819 - val_accuracy: 0.8131 - val_precision: 0.7722 - val_recall: 0.8740
# Epoch 20/30
# 66/66 [==============================] - 0s 4ms/step - loss: 0.3891 - accuracy: 0.8150 - precision: 0.7785 - recall: 0.8864 - val_loss: 0.3821 - val_accuracy: 0.8089 - val_precision: 0.7833 - val_recall: 0.8398
# Epoch 21/30
# 66/66 [==============================] - 0s 3ms/step - loss: 0.3837 - accuracy: 0.8160 - precision: 0.7800 - recall: 0.8858 - val_loss: 0.3786 - val_accuracy: 0.8106 - val_precision: 0.7744 - val_recall: 0.8623
# Epoch 22/30
# 66/66 [==============================] - 0s 3ms/step - loss: 0.3832 - accuracy: 0.8144 - precision: 0.7778 - recall: 0.8861 - val_loss: 0.3772 - val_accuracy: 0.8142 - val_precision: 0.7813 - val_recall: 0.8587
# Epoch 23/30
# 66/66 [==============================] - 0s 3ms/step - loss: 0.3817 - accuracy: 0.8172 - precision: 0.7827 - recall: 0.8837 - val_loss: 0.3750 - val_accuracy: 0.8124 - val_precision: 0.7773 - val_recall: 0.8616
# Epoch 24/30
# 66/66 [==============================] - 0s 3ms/step - loss: 0.3786 - accuracy: 0.8175 - precision: 0.7823 - recall: 0.8855 - val_loss: 0.3732 - val_accuracy: 0.8170 - val_precision: 0.7766 - val_recall: 0.8762
# Epoch 25/30
# 66/66 [==============================] - 0s 3ms/step - loss: 0.3788 - accuracy: 0.8167 - precision: 0.7811 - recall: 0.8858 - val_loss: 0.3737 - val_accuracy: 0.8167 - val_precision: 0.7692 - val_recall: 0.8908
# Epoch 26/30
# 66/66 [==============================] - 0s 4ms/step - loss: 0.3784 - accuracy: 0.8170 - precision: 0.7822 - recall: 0.8843 - val_loss: 0.3732 - val_accuracy: 0.8106 - val_precision: 0.7817 - val_recall: 0.8478
# Epoch 27/30
# 66/66 [==============================] - 0s 3ms/step - loss: 0.3744 - accuracy: 0.8196 - precision: 0.7844 - recall: 0.8870 - val_loss: 0.3742 - val_accuracy: 0.8181 - val_precision: 0.7651 - val_recall: 0.9039
# Epoch 28/30
# 66/66 [==============================] - 0s 3ms/step - loss: 0.3733 - accuracy: 0.8201 - precision: 0.7846 - recall: 0.8879 - val_loss: 0.3693 - val_accuracy: 0.8163 - val_precision: 0.7829 - val_recall: 0.8616
# Epoch 29/30
# 66/66 [==============================] - 0s 4ms/step - loss: 0.3713 - accuracy: 0.8219 - precision: 0.7871 - recall: 0.8879 - val_loss: 0.3705 - val_accuracy: 0.8216 - val_precision: 0.7675 - val_recall: 0.9090
# Epoch 30/30
# 66/66 [==============================] - 0s 3ms/step - loss: 0.3710 - accuracy: 0.8223 - precision: 0.7874 - recall: 0.8885 - val_loss: 0.3654 - val_accuracy: 0.8213 - val_precision: 0.7748 - val_recall: 0.8922

# %%
#Evaulation after resampling
scores = model.evaluate(X_test_s, y_test_s)
print('Accurcay : {}'.format(scores[1]))
print('Precision : {}'.format(scores[2]))
print('Recall : {}'.format(scores[3]))
# Out:
# 89/89 [==============================] - 1s 8ms/step - loss: 0.3548 - accuracy: 0.8362 - precision_2: 0.7893 - recall_2: 0.9108
# Accurcay : 0.8361701965332031
# Precision : 0.7892767786979675
# Recall : 0.9107913374900818

# %% [markdown]
# **[The model now is trained in both negative and positive cases. After applying SMOTE to balance the dataset, the model's performance improved significantly for the minority class, with better precision, recall , the model is now able to predict properly on new cases.]**

# %% [markdown]
# ###Model Design

# %% [markdown]
# Propose one model design method to improve the performance of your model even more.

# %%
def create_model_v2():
    model = Sequential()
    model.add(Dense(32, input_dim=10, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dense(16, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dense(4, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dense(1, activation='sigmoid'))
    return model

model_v2 = create_model_v2()
model_v2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 32)                352
#
#  batch_normalization (Batch  (None, 32)                128
#  Normalization)
#
#  dense_9 (Dense)             (None, 16)                528
#
#  batch_normalization_1 (Bat  (None, 16)                64
#  chNormalization)
#
#  dense_10 (Dense)            (None, 4)                 68
#
#  batch_normalization_2 (Bat  (None, 4)                 16
#  chNormalization)
#
#  dense_11 (Dense)            (None, 1)                 5
#
# =================================================================
# Total params: 1161 (4.54 KB)
# Trainable params: 1057 (4.13 KB)
# Non-trainable params: 104 (416.00 Byte)
# _________________________________________________________________

# %%
#Training and fitting the new model
model_v2.compile(loss='binary_crossentropy',optimizer='adam', metrics=['accuracy', Precision(thresholds = 0.5), Recall(thresholds = 0.5)])
model_v2.fit(X_train_s, y_train_s, validation_data=(X_test_s, y_test_s), epochs=30, batch_size=100)
# Out:
# Epoch 1/30
# 66/66 [==============================] - 3s 10ms/step - loss: 0.5915 - accuracy: 0.6751 - precision_1: 0.6273 - recall_1: 0.8807 - val_loss: 0.6585 - val_accuracy: 0.6071 - val_precision_1: 0.5537 - val_recall_1: 0.9949
# Epoch 2/30
# 66/66 [==============================] - 1s 9ms/step - loss: 0.4998 - accuracy: 0.7609 - precision_1: 0.7206 - recall_1: 0.8611 - val_loss: 0.5865 - val_accuracy: 0.7326 - val_precision_1: 0.6477 - val_recall_1: 0.9883
# Epoch 3/30
# 66/66 [==============================] - 0s 4ms/step - loss: 0.4561 - accuracy: 0.7921 - precision_1: 0.7551 - recall_1: 0.8714 - val_loss: 0.5144 - val_accuracy: 0.7695 - val_precision_1: 0.7001 - val_recall_1: 0.9213
# Epoch 4/30
# 66/66 [==============================] - 1s 10ms/step - loss: 0.4375 - accuracy: 0.7977 - precision_1: 0.7632 - recall_1: 0.8699 - val_loss: 0.4696 - val_accuracy: 0.7865 - val_precision_1: 0.7364 - val_recall_1: 0.8747
# Epoch 5/30
# 66/66 [==============================] - 0s 6ms/step - loss: 0.4266 - accuracy: 0.8020 - precision_1: 0.7680 - recall_1: 0.8717 - val_loss: 0.4457 - val_accuracy: 0.7926 - val_precision_1: 0.7450 - val_recall_1: 0.8725
# Epoch 6/30
# 66/66 [==============================] - 1s 20ms/step - loss: 0.4151 - accuracy: 0.8093 - precision_1: 0.7725 - recall_1: 0.8828 - val_loss: 0.4353 - val_accuracy: 0.8004 - val_precision_1: 0.7368 - val_recall_1: 0.9177
# Epoch 7/30
# 66/66 [==============================] - 1s 15ms/step - loss: 0.4065 - accuracy: 0.8093 - precision_1: 0.7698 - recall_1: 0.8885 - val_loss: 0.4103 - val_accuracy: 0.8121 - val_precision_1: 0.7643 - val_recall_1: 0.8878
# Epoch 8/30
# 66/66 [==============================] - 1s 12ms/step - loss: 0.3964 - accuracy: 0.8184 - precision_1: 0.7769 - recall_1: 0.8990 - val_loss: 0.3976 - val_accuracy: 0.8223 - val_precision_1: 0.7718 - val_recall_1: 0.9017
# Epoch 9/30
# 66/66 [==============================] - 1s 8ms/step - loss: 0.3883 - accuracy: 0.8217 - precision_1: 0.7790 - recall_1: 0.9038 - val_loss: 0.3898 - val_accuracy: 0.8230 - val_precision_1: 0.7704 - val_recall_1: 0.9068
# Epoch 10/30
# 66/66 [==============================] - 1s 8ms/step - loss: 0.3818 - accuracy: 0.8271 - precision_1: 0.7839 - recall_1: 0.9083 - val_loss: 0.3957 - val_accuracy: 0.8106 - val_precision_1: 0.7927 - val_recall_1: 0.8274
# Epoch 11/30
# 66/66 [==============================] - 1s 9ms/step - loss: 0.3754 - accuracy: 0.8304 - precision_1: 0.7899 - recall_1: 0.9053 - val_loss: 0.3748 - val_accuracy: 0.8351 - val_precision_1: 0.7796 - val_recall_1: 0.9221
# Epoch 12/30
# 66/66 [==============================] - 1s 8ms/step - loss: 0.3677 - accuracy: 0.8309 - precision_1: 0.7933 - recall_1: 0.8999 - val_loss: 0.3673 - val_accuracy: 0.8365 - val_precision_1: 0.7872 - val_recall_1: 0.9104
# Epoch 13/30
# 66/66 [==============================] - 1s 10ms/step - loss: 0.3658 - accuracy: 0.8384 - precision_1: 0.7984 - recall_1: 0.9104 - val_loss: 0.3506 - val_accuracy: 0.8404 - val_precision_1: 0.8071 - val_recall_1: 0.8835
# Epoch 14/30
# 66/66 [==============================] - 1s 15ms/step - loss: 0.3549 - accuracy: 0.8409 - precision_1: 0.8035 - recall_1: 0.9071 - val_loss: 0.3603 - val_accuracy: 0.8404 - val_precision_1: 0.7840 - val_recall_1: 0.9279
# Epoch 15/30
# 66/66 [==============================] - 1s 9ms/step - loss: 0.3546 - accuracy: 0.8391 - precision_1: 0.8030 - recall_1: 0.9032 - val_loss: 0.3716 - val_accuracy: 0.8348 - val_precision_1: 0.7850 - val_recall_1: 0.9097
# Epoch 16/30
# 66/66 [==============================] - 1s 11ms/step - loss: 0.3457 - accuracy: 0.8462 - precision_1: 0.8079 - recall_1: 0.9128 - val_loss: 0.3405 - val_accuracy: 0.8507 - val_precision_1: 0.8013 - val_recall_1: 0.9221
# Epoch 17/30
# 66/66 [==============================] - 1s 12ms/step - loss: 0.3397 - accuracy: 0.8456 - precision_1: 0.8090 - recall_1: 0.9092 - val_loss: 0.3566 - val_accuracy: 0.8411 - val_precision_1: 0.8065 - val_recall_1: 0.8864
# Epoch 18/30
# 66/66 [==============================] - 1s 10ms/step - loss: 0.3454 - accuracy: 0.8416 - precision_1: 0.8064 - recall_1: 0.9038 - val_loss: 0.3408 - val_accuracy: 0.8518 - val_precision_1: 0.7960 - val_recall_1: 0.9352
# Epoch 19/30
# 66/66 [==============================] - 0s 7ms/step - loss: 0.3375 - accuracy: 0.8488 - precision_1: 0.8128 - recall_1: 0.9107 - val_loss: 0.3311 - val_accuracy: 0.8599 - val_precision_1: 0.8175 - val_recall_1: 0.9170
# Epoch 20/30
# 66/66 [==============================] - 1s 12ms/step - loss: 0.3336 - accuracy: 0.8514 - precision_1: 0.8189 - recall_1: 0.9065 - val_loss: 0.3344 - val_accuracy: 0.8504 - val_precision_1: 0.8078 - val_recall_1: 0.9090
# Epoch 21/30
# 66/66 [==============================] - 0s 4ms/step - loss: 0.3230 - accuracy: 0.8587 - precision_1: 0.8216 - recall_1: 0.9203 - val_loss: 0.3489 - val_accuracy: 0.8521 - val_precision_1: 0.7897 - val_recall_1: 0.9490
# Epoch 22/30
# 66/66 [==============================] - 0s 4ms/step - loss: 0.3239 - accuracy: 0.8582 - precision_1: 0.8267 - recall_1: 0.9104 - val_loss: 0.3136 - val_accuracy: 0.8656 - val_precision_1: 0.8253 - val_recall_1: 0.9184
# Epoch 23/30
# 66/66 [==============================] - 0s 4ms/step - loss: 0.3212 - accuracy: 0.8588 - precision_1: 0.8262 - recall_1: 0.9128 - val_loss: 0.3178 - val_accuracy: 0.8582 - val_precision_1: 0.8174 - val_recall_1: 0.9126
# Epoch 24/30
# 66/66 [==============================] - 0s 4ms/step - loss: 0.3276 - accuracy: 0.8553 - precision_1: 0.8226 - recall_1: 0.9101 - val_loss: 0.3140 - val_accuracy: 0.8681 - val_precision_1: 0.8166 - val_recall_1: 0.9403
# Epoch 25/30
# 66/66 [==============================] - 0s 4ms/step - loss: 0.3143 - accuracy: 0.8649 - precision_1: 0.8311 - recall_1: 0.9197 - val_loss: 0.3118 - val_accuracy: 0.8695 - val_precision_1: 0.8261 - val_recall_1: 0.9272
# Epoch 26/30
# 66/66 [==============================] - 0s 4ms/step - loss: 0.3111 - accuracy: 0.8635 - precision_1: 0.8314 - recall_1: 0.9158 - val_loss: 0.3053 - val_accuracy: 0.8677 - val_precision_1: 0.8289 - val_recall_1: 0.9177
# Epoch 27/30
# 66/66 [==============================] - 0s 5ms/step - loss: 0.3102 - accuracy: 0.8693 - precision_1: 0.8331 - recall_1: 0.9273 - val_loss: 0.3055 - val_accuracy: 0.8762 - val_precision_1: 0.8320 - val_recall_1: 0.9345
# Epoch 28/30
# 66/66 [==============================] - 0s 7ms/step - loss: 0.3101 - accuracy: 0.8666 - precision_1: 0.8345 - recall_1: 0.9182 - val_loss: 0.3130 - val_accuracy: 0.8720 - val_precision_1: 0.8198 - val_recall_1: 0.9446
# Epoch 29/30
# 66/66 [==============================] - 0s 6ms/step - loss: 0.3074 - accuracy: 0.8661 - precision_1: 0.8295 - recall_1: 0.9255 - val_loss: 0.3092 - val_accuracy: 0.8727 - val_precision_1: 0.8336 - val_recall_1: 0.9228
# Epoch 30/30
# 66/66 [==============================] - 0s 6ms/step - loss: 0.3043 - accuracy: 0.8687 - precision_1: 0.8335 - recall_1: 0.9252 - val_loss: 0.3029 - val_accuracy: 0.8755 - val_precision_1: 0.8210 - val_recall_1: 0.9519

# %%
#Evaluation for the new model
scores_v2 = model_v2.evaluate(X_test_s, y_test_s)
print('Accurcay : {}'.format(scores_v2[1]))
print('Precision : {}'.format(scores_v2[2]))
print('Recall : {}'.format(scores_v2[3]))
# Out:
# 89/89 [==============================] - 0s 2ms/step - loss: 0.3029 - accuracy: 0.8755 - precision_1: 0.8210 - recall_1: 0.9519
# Accurcay : 0.8755319118499756
# Precision : 0.82097989320755
# Recall : 0.9519301056861877

# %% [markdown]
# Comment the performance of your model

# %% [markdown]
# **[After performing the batch normalization the model's performance is getting better than before.]**

# %% [markdown]
# ###Hyperparameter Tuning

# %% [markdown]
# Now we will tune some hyperparameters of our model. Pick two hyperparameters to optimize, and run a grid search to optimize them. Then fit your model on the best parameters.

# %%
#Hyperparameter tuning
def create_model_v3():
    model = Sequential()
    model.add(Dense(32, input_dim=10, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dense(16, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dense(4, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy',optimizer='adam', metrics=['accuracy', Precision(thresholds = 0.5), Recall(thresholds = 0.5)])
    return model

model_v3 = KerasClassifier(model=create_model_v3, verbose=0)

param_grid = {
    'epochs': [25,50,100],
    'batch_size': [50,100,200]
}
grid_search = GridSearchCV(model_v3, param_grid=param_grid, scoring='accuracy', cv=3)
grid_search.fit(X_train_s, y_train_s)
# Out:
# GridSearchCV(cv=3,
#              estimator=KerasClassifier(model=<function create_model_v3 at 0x7ec5ca388b80>, verbose=0),
#              param_grid={'batch_size': [50, 100, 200], 'epochs': [25, 50, 100]},
#              scoring='accuracy')

# %%
#printing the best hyperparameters
best_epochs = grid_search.best_params_['epochs']
best_batch_size = grid_search.best_params_['batch_size']
print("Best Number of Epochs: ", best_epochs)
print("Best Batch Size: ", best_batch_size)
# Out:
# Best Number of Epochs:  100
# Best Batch Size:  200

# %%
#Fitting the new model on the best hyperparameters
best_model = create_model_v3()
best_model.fit(X_train_s, y_train_s, validation_data=(X_test_s, y_test_s), epochs=best_epochs, batch_size=best_batch_size)
# Out:
# Epoch 1/100
# 33/33 [==============================] - 3s 15ms/step - loss: 0.6745 - accuracy: 0.6094 - precision_30: 0.6588 - recall_30: 0.4719 - val_loss: 0.6898 - val_accuracy: 0.4603 - val_precision_30: 0.4700 - val_recall_30: 0.8500
# Epoch 2/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.6060 - accuracy: 0.6857 - precision_30: 0.7566 - recall_30: 0.5579 - val_loss: 0.6944 - val_accuracy: 0.4872 - val_precision_30: 0.4870 - val_recall_30: 0.9971
# Epoch 3/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.5658 - accuracy: 0.7272 - precision_30: 0.7632 - recall_30: 0.6676 - val_loss: 0.7049 - val_accuracy: 0.4858 - val_precision_30: 0.4863 - val_recall_30: 0.9971
# Epoch 4/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.5342 - accuracy: 0.7564 - precision_30: 0.7791 - recall_30: 0.7232 - val_loss: 0.7160 - val_accuracy: 0.5206 - val_precision_30: 0.5039 - val_recall_30: 0.9978
# Epoch 5/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.4980 - accuracy: 0.7798 - precision_30: 0.7811 - recall_30: 0.7842 - val_loss: 0.7230 - val_accuracy: 0.5745 - val_precision_30: 0.5337 - val_recall_30: 0.9964
# Epoch 6/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.4698 - accuracy: 0.7907 - precision_30: 0.7818 - recall_30: 0.8130 - val_loss: 0.7067 - val_accuracy: 0.6014 - val_precision_30: 0.5501 - val_recall_30: 0.9964
# Epoch 7/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.4487 - accuracy: 0.7997 - precision_30: 0.7848 - recall_30: 0.8320 - val_loss: 0.6416 - val_accuracy: 0.6507 - val_precision_30: 0.5828 - val_recall_30: 0.9942
# Epoch 8/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.4310 - accuracy: 0.8059 - precision_30: 0.7871 - recall_30: 0.8446 - val_loss: 0.5702 - val_accuracy: 0.6869 - val_precision_30: 0.6103 - val_recall_30: 0.9876
# Epoch 9/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.4148 - accuracy: 0.8172 - precision_30: 0.7940 - recall_30: 0.8620 - val_loss: 0.5426 - val_accuracy: 0.7053 - val_precision_30: 0.6262 - val_recall_30: 0.9796
# Epoch 10/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.4039 - accuracy: 0.8175 - precision_30: 0.7884 - recall_30: 0.8735 - val_loss: 0.5073 - val_accuracy: 0.7394 - val_precision_30: 0.6561 - val_recall_30: 0.9767
# Epoch 11/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3929 - accuracy: 0.8214 - precision_30: 0.7933 - recall_30: 0.8747 - val_loss: 0.4706 - val_accuracy: 0.7745 - val_precision_30: 0.6918 - val_recall_30: 0.9680
# Epoch 12/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3821 - accuracy: 0.8280 - precision_30: 0.7967 - recall_30: 0.8858 - val_loss: 0.4449 - val_accuracy: 0.7957 - val_precision_30: 0.7205 - val_recall_30: 0.9483
# Epoch 13/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3761 - accuracy: 0.8348 - precision_30: 0.8037 - recall_30: 0.8909 - val_loss: 0.4309 - val_accuracy: 0.8028 - val_precision_30: 0.7291 - val_recall_30: 0.9468
# Epoch 14/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3716 - accuracy: 0.8362 - precision_30: 0.8067 - recall_30: 0.8891 - val_loss: 0.4081 - val_accuracy: 0.8191 - val_precision_30: 0.7549 - val_recall_30: 0.9308
# Epoch 15/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3620 - accuracy: 0.8427 - precision_30: 0.8107 - recall_30: 0.8987 - val_loss: 0.3942 - val_accuracy: 0.8305 - val_precision_30: 0.7730 - val_recall_30: 0.9228
# Epoch 16/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3522 - accuracy: 0.8468 - precision_30: 0.8165 - recall_30: 0.8990 - val_loss: 0.3888 - val_accuracy: 0.8319 - val_precision_30: 0.7808 - val_recall_30: 0.9104
# Epoch 17/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3473 - accuracy: 0.8476 - precision_30: 0.8196 - recall_30: 0.8957 - val_loss: 0.3751 - val_accuracy: 0.8390 - val_precision_30: 0.7863 - val_recall_30: 0.9192
# Epoch 18/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3461 - accuracy: 0.8494 - precision_30: 0.8202 - recall_30: 0.8993 - val_loss: 0.3588 - val_accuracy: 0.8418 - val_precision_30: 0.8023 - val_recall_30: 0.8958
# Epoch 19/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3417 - accuracy: 0.8508 - precision_30: 0.8226 - recall_30: 0.8987 - val_loss: 0.3626 - val_accuracy: 0.8418 - val_precision_30: 0.7910 - val_recall_30: 0.9177
# Epoch 20/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3356 - accuracy: 0.8578 - precision_30: 0.8257 - recall_30: 0.9110 - val_loss: 0.3484 - val_accuracy: 0.8582 - val_precision_30: 0.8081 - val_recall_30: 0.9294
# Epoch 21/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3303 - accuracy: 0.8593 - precision_30: 0.8304 - recall_30: 0.9068 - val_loss: 0.3534 - val_accuracy: 0.8426 - val_precision_30: 0.8030 - val_recall_30: 0.8966
# Epoch 22/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3264 - accuracy: 0.8614 - precision_30: 0.8329 - recall_30: 0.9080 - val_loss: 0.3441 - val_accuracy: 0.8479 - val_precision_30: 0.8109 - val_recall_30: 0.8966
# Epoch 23/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3249 - accuracy: 0.8573 - precision_30: 0.8313 - recall_30: 0.9005 - val_loss: 0.3352 - val_accuracy: 0.8518 - val_precision_30: 0.8131 - val_recall_30: 0.9031
# Epoch 24/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3241 - accuracy: 0.8608 - precision_30: 0.8329 - recall_30: 0.9065 - val_loss: 0.3305 - val_accuracy: 0.8610 - val_precision_30: 0.8106 - val_recall_30: 0.9323
# Epoch 25/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3119 - accuracy: 0.8667 - precision_30: 0.8382 - recall_30: 0.9125 - val_loss: 0.3355 - val_accuracy: 0.8592 - val_precision_30: 0.8077 - val_recall_30: 0.9330
# Epoch 26/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3096 - accuracy: 0.8720 - precision_30: 0.8468 - recall_30: 0.9119 - val_loss: 0.3163 - val_accuracy: 0.8628 - val_precision_30: 0.8467 - val_recall_30: 0.8769
# Epoch 27/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3162 - accuracy: 0.8693 - precision_30: 0.8433 - recall_30: 0.9107 - val_loss: 0.3155 - val_accuracy: 0.8649 - val_precision_30: 0.8204 - val_recall_30: 0.9250
# Epoch 28/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3083 - accuracy: 0.8719 - precision_30: 0.8437 - recall_30: 0.9164 - val_loss: 0.3081 - val_accuracy: 0.8762 - val_precision_30: 0.8338 - val_recall_30: 0.9315
# Epoch 29/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3055 - accuracy: 0.8736 - precision_30: 0.8453 - recall_30: 0.9179 - val_loss: 0.3078 - val_accuracy: 0.8745 - val_precision_30: 0.8422 - val_recall_30: 0.9133
# Epoch 30/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3026 - accuracy: 0.8740 - precision_30: 0.8471 - recall_30: 0.9161 - val_loss: 0.2998 - val_accuracy: 0.8784 - val_precision_30: 0.8503 - val_recall_30: 0.9104
# Epoch 31/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.3006 - accuracy: 0.8792 - precision_30: 0.8491 - recall_30: 0.9255 - val_loss: 0.2987 - val_accuracy: 0.8752 - val_precision_30: 0.8523 - val_recall_30: 0.8995
# Epoch 32/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2896 - accuracy: 0.8850 - precision_30: 0.8564 - recall_30: 0.9282 - val_loss: 0.3007 - val_accuracy: 0.8727 - val_precision_30: 0.8444 - val_recall_30: 0.9053
# Epoch 33/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2955 - accuracy: 0.8764 - precision_30: 0.8490 - recall_30: 0.9191 - val_loss: 0.2998 - val_accuracy: 0.8759 - val_precision_30: 0.8515 - val_recall_30: 0.9024
# Epoch 34/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2976 - accuracy: 0.8761 - precision_30: 0.8477 - recall_30: 0.9203 - val_loss: 0.3206 - val_accuracy: 0.8667 - val_precision_30: 0.8474 - val_recall_30: 0.8857
# Epoch 35/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2888 - accuracy: 0.8781 - precision_30: 0.8479 - recall_30: 0.9249 - val_loss: 0.3003 - val_accuracy: 0.8784 - val_precision_30: 0.8366 - val_recall_30: 0.9323
# Epoch 36/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2860 - accuracy: 0.8816 - precision_30: 0.8537 - recall_30: 0.9243 - val_loss: 0.2891 - val_accuracy: 0.8851 - val_precision_30: 0.8625 - val_recall_30: 0.9090
# Epoch 37/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2818 - accuracy: 0.8848 - precision_30: 0.8597 - recall_30: 0.9228 - val_loss: 0.2965 - val_accuracy: 0.8809 - val_precision_30: 0.8409 - val_recall_30: 0.9315
# Epoch 38/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2875 - accuracy: 0.8816 - precision_30: 0.8551 - recall_30: 0.9222 - val_loss: 0.3043 - val_accuracy: 0.8805 - val_precision_30: 0.8325 - val_recall_30: 0.9446
# Epoch 39/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2778 - accuracy: 0.8850 - precision_30: 0.8544 - recall_30: 0.9312 - val_loss: 0.2814 - val_accuracy: 0.8869 - val_precision_30: 0.8537 - val_recall_30: 0.9264
# Epoch 40/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2804 - accuracy: 0.8851 - precision_30: 0.8586 - recall_30: 0.9252 - val_loss: 0.2912 - val_accuracy: 0.8851 - val_precision_30: 0.8395 - val_recall_30: 0.9446
# Epoch 41/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2745 - accuracy: 0.8871 - precision_30: 0.8599 - recall_30: 0.9279 - val_loss: 0.2837 - val_accuracy: 0.8844 - val_precision_30: 0.8406 - val_recall_30: 0.9410
# Epoch 42/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2791 - accuracy: 0.8863 - precision_30: 0.8585 - recall_30: 0.9282 - val_loss: 0.2829 - val_accuracy: 0.8879 - val_precision_30: 0.8443 - val_recall_30: 0.9439
# Epoch 43/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2817 - accuracy: 0.8809 - precision_30: 0.8553 - recall_30: 0.9200 - val_loss: 0.2863 - val_accuracy: 0.8798 - val_precision_30: 0.8465 - val_recall_30: 0.9199
# Epoch 44/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2772 - accuracy: 0.8891 - precision_30: 0.8596 - recall_30: 0.9330 - val_loss: 0.2788 - val_accuracy: 0.8968 - val_precision_30: 0.8531 - val_recall_30: 0.9519
# Epoch 45/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2697 - accuracy: 0.8901 - precision_30: 0.8645 - recall_30: 0.9282 - val_loss: 0.2716 - val_accuracy: 0.8943 - val_precision_30: 0.8591 - val_recall_30: 0.9366
# Epoch 46/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2672 - accuracy: 0.8926 - precision_30: 0.8643 - recall_30: 0.9342 - val_loss: 0.2745 - val_accuracy: 0.8961 - val_precision_30: 0.8548 - val_recall_30: 0.9476
# Epoch 47/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2716 - accuracy: 0.8857 - precision_30: 0.8607 - recall_30: 0.9234 - val_loss: 0.2795 - val_accuracy: 0.8869 - val_precision_30: 0.8585 - val_recall_30: 0.9192
# Epoch 48/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2722 - accuracy: 0.8875 - precision_30: 0.8566 - recall_30: 0.9339 - val_loss: 0.2848 - val_accuracy: 0.8851 - val_precision_30: 0.8252 - val_recall_30: 0.9694
# Epoch 49/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2657 - accuracy: 0.8933 - precision_30: 0.8665 - recall_30: 0.9327 - val_loss: 0.2757 - val_accuracy: 0.8915 - val_precision_30: 0.8559 - val_recall_30: 0.9345
# Epoch 50/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2577 - accuracy: 0.8979 - precision_30: 0.8709 - recall_30: 0.9369 - val_loss: 0.2864 - val_accuracy: 0.8833 - val_precision_30: 0.8494 - val_recall_30: 0.9243
# Epoch 51/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2635 - accuracy: 0.8919 - precision_30: 0.8672 - recall_30: 0.9285 - val_loss: 0.2896 - val_accuracy: 0.8901 - val_precision_30: 0.8648 - val_recall_30: 0.9177
# Epoch 52/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2646 - accuracy: 0.8929 - precision_30: 0.8672 - recall_30: 0.9306 - val_loss: 0.2720 - val_accuracy: 0.8904 - val_precision_30: 0.8415 - val_recall_30: 0.9548
# Epoch 53/100
# 33/33 [==============================] - 0s 8ms/step - loss: 0.2660 - accuracy: 0.8884 - precision_30: 0.8649 - recall_30: 0.9237 - val_loss: 0.2719 - val_accuracy: 0.8933 - val_precision_30: 0.8499 - val_recall_30: 0.9483
# Epoch 54/100
# 33/33 [==============================] - 0s 8ms/step - loss: 0.2602 - accuracy: 0.8916 - precision_30: 0.8625 - recall_30: 0.9348 - val_loss: 0.2811 - val_accuracy: 0.8844 - val_precision_30: 0.8406 - val_recall_30: 0.9410
# Epoch 55/100
# 33/33 [==============================] - 0s 7ms/step - loss: 0.2584 - accuracy: 0.8935 - precision_30: 0.8668 - recall_30: 0.9327 - val_loss: 0.2709 - val_accuracy: 0.8897 - val_precision_30: 0.8617 - val_recall_30: 0.9213
# Epoch 56/100
# 33/33 [==============================] - 0s 7ms/step - loss: 0.2597 - accuracy: 0.8935 - precision_30: 0.8657 - recall_30: 0.9342 - val_loss: 0.2627 - val_accuracy: 0.8936 - val_precision_30: 0.8495 - val_recall_30: 0.9497
# Epoch 57/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2526 - accuracy: 0.8992 - precision_30: 0.8719 - recall_30: 0.9387 - val_loss: 0.2615 - val_accuracy: 0.9028 - val_precision_30: 0.8661 - val_recall_30: 0.9468
# Epoch 58/100
# 33/33 [==============================] - 0s 7ms/step - loss: 0.2547 - accuracy: 0.8994 - precision_30: 0.8709 - recall_30: 0.9405 - val_loss: 0.2736 - val_accuracy: 0.8972 - val_precision_30: 0.8460 - val_recall_30: 0.9643
# Epoch 59/100
# 33/33 [==============================] - 0s 7ms/step - loss: 0.2523 - accuracy: 0.8954 - precision_30: 0.8716 - recall_30: 0.9303 - val_loss: 0.2811 - val_accuracy: 0.8979 - val_precision_30: 0.8466 - val_recall_30: 0.9650
# Epoch 60/100
# 33/33 [==============================] - 0s 7ms/step - loss: 0.2565 - accuracy: 0.8968 - precision_30: 0.8674 - recall_30: 0.9396 - val_loss: 0.2746 - val_accuracy: 0.8865 - val_precision_30: 0.8541 - val_recall_30: 0.9250
# Epoch 61/100
# 33/33 [==============================] - 0s 8ms/step - loss: 0.2481 - accuracy: 0.8989 - precision_30: 0.8764 - recall_30: 0.9315 - val_loss: 0.2608 - val_accuracy: 0.8986 - val_precision_30: 0.8504 - val_recall_30: 0.9607
# Epoch 62/100
# 33/33 [==============================] - 0s 7ms/step - loss: 0.2432 - accuracy: 0.9029 - precision_30: 0.8771 - recall_30: 0.9396 - val_loss: 0.2675 - val_accuracy: 0.8989 - val_precision_30: 0.8514 - val_recall_30: 0.9599
# Epoch 63/100
# 33/33 [==============================] - 0s 8ms/step - loss: 0.2503 - accuracy: 0.8988 - precision_30: 0.8749 - recall_30: 0.9333 - val_loss: 0.2541 - val_accuracy: 0.9064 - val_precision_30: 0.8704 - val_recall_30: 0.9490
# Epoch 64/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2447 - accuracy: 0.8973 - precision_30: 0.8710 - recall_30: 0.9354 - val_loss: 0.2734 - val_accuracy: 0.8982 - val_precision_30: 0.8476 - val_recall_30: 0.9643
# Epoch 65/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2501 - accuracy: 0.8974 - precision_30: 0.8700 - recall_30: 0.9372 - val_loss: 0.2752 - val_accuracy: 0.8897 - val_precision_30: 0.8642 - val_recall_30: 0.9177
# Epoch 66/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2473 - accuracy: 0.9038 - precision_30: 0.8799 - recall_30: 0.9378 - val_loss: 0.2729 - val_accuracy: 0.8908 - val_precision_30: 0.8483 - val_recall_30: 0.9446
# Epoch 67/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2547 - accuracy: 0.8957 - precision_30: 0.8721 - recall_30: 0.9303 - val_loss: 0.2731 - val_accuracy: 0.8894 - val_precision_30: 0.8398 - val_recall_30: 0.9548
# Epoch 68/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2445 - accuracy: 0.9024 - precision_30: 0.8772 - recall_30: 0.9384 - val_loss: 0.2619 - val_accuracy: 0.9007 - val_precision_30: 0.8565 - val_recall_30: 0.9563
# Epoch 69/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2508 - accuracy: 0.9018 - precision_30: 0.8758 - recall_30: 0.9390 - val_loss: 0.2637 - val_accuracy: 0.9039 - val_precision_30: 0.8625 - val_recall_30: 0.9548
# Epoch 70/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2424 - accuracy: 0.9035 - precision_30: 0.8756 - recall_30: 0.9432 - val_loss: 0.2698 - val_accuracy: 0.8989 - val_precision_30: 0.8487 - val_recall_30: 0.9643
# Epoch 71/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2332 - accuracy: 0.9074 - precision_30: 0.8750 - recall_30: 0.9531 - val_loss: 0.2666 - val_accuracy: 0.8996 - val_precision_30: 0.8702 - val_recall_30: 0.9330
# Epoch 72/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2384 - accuracy: 0.9044 - precision_30: 0.8796 - recall_30: 0.9396 - val_loss: 0.2599 - val_accuracy: 0.9078 - val_precision_30: 0.8678 - val_recall_30: 0.9563
# Epoch 73/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2389 - accuracy: 0.9043 - precision_30: 0.8810 - recall_30: 0.9372 - val_loss: 0.2562 - val_accuracy: 0.9078 - val_precision_30: 0.8732 - val_recall_30: 0.9483
# Epoch 74/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2382 - accuracy: 0.9065 - precision_30: 0.8800 - recall_30: 0.9438 - val_loss: 0.2598 - val_accuracy: 0.9085 - val_precision_30: 0.8637 - val_recall_30: 0.9643
# Epoch 75/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2388 - accuracy: 0.9047 - precision_30: 0.8758 - recall_30: 0.9456 - val_loss: 0.2607 - val_accuracy: 0.9000 - val_precision_30: 0.8688 - val_recall_30: 0.9359
# Epoch 76/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2395 - accuracy: 0.9029 - precision_30: 0.8797 - recall_30: 0.9360 - val_loss: 0.2560 - val_accuracy: 0.9046 - val_precision_30: 0.8730 - val_recall_30: 0.9410
# Epoch 77/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2388 - accuracy: 0.9061 - precision_30: 0.8832 - recall_30: 0.9384 - val_loss: 0.2637 - val_accuracy: 0.8979 - val_precision_30: 0.8688 - val_recall_30: 0.9308
# Epoch 78/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2379 - accuracy: 0.9009 - precision_30: 0.8729 - recall_30: 0.9411 - val_loss: 0.2578 - val_accuracy: 0.9067 - val_precision_30: 0.8661 - val_recall_30: 0.9563
# Epoch 79/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2289 - accuracy: 0.9109 - precision_30: 0.8859 - recall_30: 0.9456 - val_loss: 0.2796 - val_accuracy: 0.8989 - val_precision_30: 0.8505 - val_recall_30: 0.9614
# Epoch 80/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2360 - accuracy: 0.9085 - precision_30: 0.8824 - recall_30: 0.9450 - val_loss: 0.2587 - val_accuracy: 0.9050 - val_precision_30: 0.8571 - val_recall_30: 0.9658
# Epoch 81/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2304 - accuracy: 0.9065 - precision_30: 0.8803 - recall_30: 0.9435 - val_loss: 0.2663 - val_accuracy: 0.9046 - val_precision_30: 0.8651 - val_recall_30: 0.9527
# Epoch 82/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2395 - accuracy: 0.9038 - precision_30: 0.8788 - recall_30: 0.9393 - val_loss: 0.2527 - val_accuracy: 0.9039 - val_precision_30: 0.8573 - val_recall_30: 0.9629
# Epoch 83/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2345 - accuracy: 0.9049 - precision_30: 0.8812 - recall_30: 0.9384 - val_loss: 0.2601 - val_accuracy: 0.9046 - val_precision_30: 0.8720 - val_recall_30: 0.9425
# Epoch 84/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2329 - accuracy: 0.9070 - precision_30: 0.8804 - recall_30: 0.9444 - val_loss: 0.2599 - val_accuracy: 0.9039 - val_precision_30: 0.8587 - val_recall_30: 0.9607
# Epoch 85/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2310 - accuracy: 0.9062 - precision_30: 0.8800 - recall_30: 0.9432 - val_loss: 0.2633 - val_accuracy: 0.9018 - val_precision_30: 0.8610 - val_recall_30: 0.9519
# Epoch 86/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2324 - accuracy: 0.9079 - precision_30: 0.8825 - recall_30: 0.9435 - val_loss: 0.2375 - val_accuracy: 0.9152 - val_precision_30: 0.8735 - val_recall_30: 0.9658
# Epoch 87/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2296 - accuracy: 0.9116 - precision_30: 0.8843 - recall_30: 0.9492 - val_loss: 0.2637 - val_accuracy: 0.9064 - val_precision_30: 0.8539 - val_recall_30: 0.9745
# Epoch 88/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2303 - accuracy: 0.9087 - precision_30: 0.8844 - recall_30: 0.9426 - val_loss: 0.2419 - val_accuracy: 0.9117 - val_precision_30: 0.8702 - val_recall_30: 0.9621
# Epoch 89/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2249 - accuracy: 0.9112 - precision_30: 0.8843 - recall_30: 0.9486 - val_loss: 0.2785 - val_accuracy: 0.8851 - val_precision_30: 0.8803 - val_recall_30: 0.8842
# Epoch 90/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2319 - accuracy: 0.9108 - precision_30: 0.8864 - recall_30: 0.9447 - val_loss: 0.2684 - val_accuracy: 0.9011 - val_precision_30: 0.8647 - val_recall_30: 0.9446
# Epoch 91/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2278 - accuracy: 0.9100 - precision_30: 0.8860 - recall_30: 0.9435 - val_loss: 0.2519 - val_accuracy: 0.9085 - val_precision_30: 0.8842 - val_recall_30: 0.9345
# Epoch 92/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2263 - accuracy: 0.9116 - precision_30: 0.8867 - recall_30: 0.9459 - val_loss: 0.2604 - val_accuracy: 0.9018 - val_precision_30: 0.8865 - val_recall_30: 0.9155
# Epoch 93/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2213 - accuracy: 0.9128 - precision_30: 0.8894 - recall_30: 0.9450 - val_loss: 0.2361 - val_accuracy: 0.9184 - val_precision_30: 0.8802 - val_recall_30: 0.9636
# Epoch 94/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2172 - accuracy: 0.9132 - precision_30: 0.8875 - recall_30: 0.9486 - val_loss: 0.2510 - val_accuracy: 0.9085 - val_precision_30: 0.8576 - val_recall_30: 0.9738
# Epoch 95/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2142 - accuracy: 0.9191 - precision_30: 0.8913 - recall_30: 0.9567 - val_loss: 0.2400 - val_accuracy: 0.9145 - val_precision_30: 0.8835 - val_recall_30: 0.9497
# Epoch 96/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2319 - accuracy: 0.9070 - precision_30: 0.8869 - recall_30: 0.9354 - val_loss: 0.2625 - val_accuracy: 0.9071 - val_precision_30: 0.8523 - val_recall_30: 0.9789
# Epoch 97/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.2204 - accuracy: 0.9160 - precision_30: 0.8898 - recall_30: 0.9516 - val_loss: 0.2588 - val_accuracy: 0.9078 - val_precision_30: 0.8579 - val_recall_30: 0.9716
# Epoch 98/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2268 - accuracy: 0.9132 - precision_30: 0.8893 - recall_30: 0.9462 - val_loss: 0.2631 - val_accuracy: 0.8989 - val_precision_30: 0.8560 - val_recall_30: 0.9527
# Epoch 99/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2231 - accuracy: 0.9103 - precision_30: 0.8847 - recall_30: 0.9459 - val_loss: 0.2396 - val_accuracy: 0.9142 - val_precision_30: 0.8850 - val_recall_30: 0.9468
# Epoch 100/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2187 - accuracy: 0.9134 - precision_30: 0.8913 - recall_30: 0.9438 - val_loss: 0.2633 - val_accuracy: 0.9028 - val_precision_30: 0.8467 - val_recall_30: 0.9774

# %%
#Evaluation for the new model after hyperparameter tuning
scores_v3 = best_model.evaluate(X_test_s, y_test_s)
print('Accurcay : {}'.format(scores_v3[1]))
print('Precision : {}'.format(scores_v3[2]))
print('Recall : {}'.format(scores_v3[3]))
# Out:
# 89/89 [==============================] - 0s 2ms/step - loss: 0.2633 - accuracy: 0.9028 - precision_30: 0.8467 - recall_30: 0.9774
# Accurcay : 0.9028368592262268
# Precision : 0.8466876745223999
# Recall : 0.9774217009544373

# %% [markdown]
# Comment the performance of your model

# %% [markdown]
# **[This is the best mode, the accuracy, precision and recall are better now]**
